# %% [markdown]
# ### 1. Import libraries

# %% [raw]
# # Required libraries
# !pip install tensorflow==2.4.1 opencv-python==4.5.2.54 mediapipe==0.8.8 sklearn tqdm
# !pip list

# %%
import os
import time

import numpy as np
import cv2
import mediapipe as mp

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow import keras 
from tensorflow.keras.utils import to_categorical 
import predict

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Real-Time detection

# %% [raw]
# def randomColors():
#     return random.randrange(0, 256)

# %% [raw]
# import random
# colors = []
# for i in range(0, len(np.array(actions))):
#     colors.append((randomColors(), randomColors(), randomColors()))
# print(colors)
# def prob_viz(res, actions, input_frame, colors):
#     output_frame = input_frame.copy()
#     for num, prob in enumerate(res):
#         cv2.rectangle(output_frame, (0,60+num*15), (int(prob*100), 60+(num+1)*15), colors[num], -1)
#         cv2.putText(output_frame, actions[num], (0, 60+num*15), cv2.FONT_HERSHEY_SIMPLEX, 0.2, (255,255,255), 2, cv2.LINE_AA)
#
#     return output_frame

# %% [raw]
# import predict
# sequence = []
# sentence = []
# predictions = []
# threshold = 0.9
# p_Time = 0
# c_Time = 0
#
# cap = cv2.VideoCapture(0)
# #frame_no = 0
# height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
# width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# fps = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
# out = cv2.VideoWriter('output.avi', 0, cv2.VideoWriter_fourcc(*'MJPG'), 30, (width, height))
# # Set mediapipe model
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#     frame_no = 0
#     while cap.isOpened():
#
#         # Read feed
#         ret, frame = cap.read()
#         frame_no = 0
#
#         frame_exists, curr_frame = cap.read()
#         if frame_exists:
#             #print("for frame : " + str(frame_no) + "   timestamp is: ", str(cap.get(cv2.CAP_PROP_POS_MSEC)))
#             frame_no += 1
#
#         else:
#             break
#         frame_no += 1
#
#         # Make detections
#         image, results = mediapipe_detection(frame, holistic)
#         #print(results)
#
#         # Draw landmarks
#         draw_styled_landmarks(image, results)
#
#         # 2. Prediction logic
#         keypoints = extract_keypoints(results)
#         sequence.append(keypoints)
#         sequence = sequence[-30:]
#
#         if len(sequence) == 30:
#             res = model1.predict(np.expand_dims(sequence, axis=0))[0] # CHANGED
#             predict.play_sound(np.argmax(res))
# #             video_arr = np.array(sequence) # (MUST BE of SHAPE (30,1662))
# #             y_pred, res = predict_n_play(video_arr) # (RETURNS y_pred and res (softmax scores for each class)
# #                                                     #and play sound in background)
#
#             #print(res.shape)
#             #print(video_arr.shape)
#             #print(actions[np.argmax(res)])
#             predictions.append(np.argmax(res))
#             #print(res[np.argmax(res)])
#
#             #print(actions[np.argmax(res)])
#             if np.unique(predictions[-10:])[0]==np.argmax(res):
#                 if res[np.argmax(res)]>threshold:
#                     if len(sentence) > 0:
#                         if actions[np.argmax(res)] != sentence[-1]:
#                             sentence.append(actions[np.argmax(res)])
#                     else:
#                         sentence.append(actions[np.argmax(res)])
#
#
#             #if res[np.argmax(res)] > threshold:
#                 #if len(sentence) > 0:
#                     #if actions[np.argmax(res)] != sentence[-1]:
#                         #sentence.append(actions[np.argmax(res)])
#                 #else:
#                     #sentence.append(actions[np.argmax(res)])
#
#             #if len(sentence) > 3:
#                 #sentence = sentence[-3:]
#
#             if len(sentence) > 4:
#                 sentence = sentence[-4:]
#             image = prob_viz(res, actions, image, colors)
#
#         cv2.rectangle(image, (0,0), (640,40), (20, 105, 60), -1)
#         #cv2.putText(image, ' '.join(sentence), (3,30),
#                           #cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 3, cv2.LINE_AA)
#         cv2.rectangle(image, (275, height-15), (width-100, height-35), (20, 105, 60), -1)
#         cv2.putText(image, "Musical Notes Detection", (310,height-20),
#                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
#
#         c_Time = time.time()
#         fps = 1/(c_Time-p_Time)
#         p_Time = c_Time
#         fps = int(fps)
#         fps = str(fps)
#         cv2.putText(image, fps, (520, 130), cv2.FONT_HERSHEY_SIMPLEX, 3, (100, 255, 0), cv2.LINE_AA)
#
#         #cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
#         #cv2.putText(image, ' '.join(sentence), (1,30),
#                        #cv2.FONT_HERSHEY_COMPLEX, 0.9, (50, 255, 255), 2)
#
#         # Show to screen
#         cv2.imshow('OpenCV Feed', image)
#         out.write(image)
#
#         # Break gracefully
#         if cv2.waitKey(5) & 0xFF == ord('q'):
#             break
#     cap.release()
#     cv2.destroyAllWindows()

# %% [raw]
# cap.release()
# cv2.destroyAllWindows()
